# %%
import requests
import json
import pandas as pd

# %%
import random

def get_pokemon_details(id):
    
    response= requests.get(f'https://pokeapi.co/api/v2/pokemon/{id}')
    pokemon_data=response.json()
    id=pokemon_data['id']
    name=pokemon_data['name']

    # to retieve the base stat of HP and its value together
    for key in pokemon_data['stats']:

        for value in key.items():
            if key['stat']['name'] == 'hp':
                HP = key['base_stat']
            elif key['stat']['name'] == 'attack':
                attack = key['base_stat']
            elif key['stat']['name'] == 'defense':
                defense = key['base_stat']


        types=[t['type']['name']for t in pokemon_data['types']]

    pokemon_details={'id':id, 'name':name, 'HP': HP, 'attack': attack, 'defense': defense, 'types':types}
    return pokemon_details

def get_random_pokemon_id():
    return random.randint(1,1281)

# %%
def pokenames_id():
    response_2 = requests.get("https://pokeapi.co/api/v2/pokemon?limit=100000&offset=0")

    response_dict_2 = response_2.json()

    results = response_dict_2['results']

    names = []

    for items in results:
        names.append(items['name'])
        # print(items['name'])

    pokemon = pd.DataFrame(names)
    pokemon.index += 1
    pokemon.columns =['Names']
    pokemon.insert(1, 'id', range(1, 1 + len(pokemon)))

    return pokemon
print(pokenames_id())
df = pokenames_id()
# Out:
#                         Names    id
# 1                   bulbasaur     1
# 2                     ivysaur     2
# 3                    venusaur     3
# 4                  charmander     4
# 5                  charmeleon     5
# ...                       ...   ...
# 1277   koraidon-gliding-build  1277
# 1278  miraidon-low-power-mode  1278
# 1279      miraidon-drive-mode  1279
# 1280    miraidon-aquatic-mode  1280
# 1281      miraidon-glide-mode  1281
#
# [1281 rows x 2 columns]

# %%
print("Welcome to Pokemon Text Battle!")
print('-------------------------------------------------------')

p1_random = get_random_pokemon_id()
cpu_random = get_random_pokemon_id()
p2_random = get_random_pokemon_id()

print("Would you like to enter the game? (yes(y)/no(n)")
answer = input()
if answer == 'y' or answer == 'yes':
    print('-------------------------------------------------------')
    print("Please choose from the following options:")
    print('-------------------------------------------------------')
    print("1. Single player")
    print("2. Two players")
    players = input()
    if players == '1':
        print('-------------------------------------------------------')
        print("Welcome to Single Player Mode!")
        print('-------------------------------------------------------')
        print("Please enter your pokemon name: ")
        p1_name = input()
        

        if p1_name in df['Names'].values:
            index = df.loc[df['Names'] == p1_name]
            id_1 = index['id'].values[0]  
            print(f"Your pokemon name is: {p1_name}. Your pokemon ID is: {id_1}")
            p1 = get_pokemon_details(id_1)
            
        else:
            print("Pokemon does not exist! Randomly selecting.")
            print('-------------------------------------------------------')
            print(f"Your pokemon ID is: {p1_random}")
            p1 = get_pokemon_details(p1_random)
    
        print('-------------------------------------------------------')
        print(f"Your opponent pokemon ID is: {cpu_random}")
        p2 = get_pokemon_details(cpu_random)
    
    elif players == '2':
        print('-------------------------------------------------------')
        print("Welcome to Two Player Mode!")
        print('-------------------------------------------------------')
        print("Player 1! Please enter your pokemon name: ")
        p1_name = input()
        
        if p1_name in df['Names'].values:
            index = df.loc[df['Names'] == p1_name]
            id_1 = index['id'].values[0]  
            print(f"Your pokemon name is: {p1_name}. Your pokemon ID is: {id_1}")
            p1 = get_pokemon_details(id_1)
        else:
            print("Pokemon does not exist! Randomly selecting.")
            print('-------------------------------------------------------')
            print(f"Your pokemon ID is: {p1_random}")
            p1 = get_pokemon_details(p1_random)
        
        print('-------------------------------------------------------')
        print("Player 2! Please enter your pokemon name: ")
        p2_name = input()
        
        if p2_name in df['Names'].values:
            index_2 = df.loc[df['Names'] == p2_name]
            id_2 = index_2['id'].values[0]  
            print(f"Your pokemon name is: {p2_name}. Your pokemon ID is: {id_2}")
            p2 = get_pokemon_details(id_2)
            
        else:
            print("Pokemon does not exist! Randomly selecting.")
            print('-------------------------------------------------------')
            print(f"Your pokemon ID is: {p2_random}")
            p2 = get_pokemon_details(p2_random)
    
    else:
        print("Nope. Start game again...")
        pass

elif answer == 'n' or answer == 'no':
    print('-------------------------------------------------------')
    print("GAME OVER.....")
    pass

# %%
# Function to get attack modifiers

def attack_mod(p1, p2):

    p1_name = p1.get('name')
    p2_name = p2.get('name')

    p1_id = p1.get('id')
    p2_id = p2.get('id')

    p1_types = p1.get('types')
    p2_types = p2.get('types')

    p1_attack = p1.get('attack')
    p2_attack = p2.get('attack')

    p1_hp = p1.get('HP')
    p2_hp = p2.get('HP')

    p1_defense = p1.get('defence')
    p2_defense = p2.get('defence')


    # Grass type Attack modifier
    if 'grass' in p1_types and 'normal' in  p2_types:
        pass
        # no attack modifier needed
    elif 'grass' in p1_types and 'fire' in p2_types:
        p1_attack = p1_attack / 2
        p2_attack = p2_attack * 2
    elif 'grass' in p1_types and 'water' in p2_types:
        p1_attack = p1_attack * 2
        p2_attack = p2_attack / 2
    elif 'grass' in p1_types and 'electric' in p2_types:
        p2_attack = p2_attack / 2

    elif 'grass' in p1_types and 'grass' in p2_types:
        p1_attack = p1_attack / 2
        p2_attack = p2_attack / 2

    elif 'grass' in p1_types and 'ice' in p2_types:
        p2_attack =- p2_attack * 2

    elif 'grass' in p1_types and 'fightiing' in p2_types:
        pass
        # no attack modifier needed
    elif 'grass' in  p1_types and 'poison' in p2_types:
        p1_attack = p1_attack / 2
        p2_attack = p2_attack * 2

    elif 'grass' in p1_types and 'ground' in p2_types:
        p1_attack = p1_attack * 2
        p2_attack = p2_attack / 2

    elif 'grass' in p1_types and 'flying' in p2_types:
        p1_attack = p1_attack / 2
        p2_attack = p2_attack * 2

    elif 'grass' in p1.get('types') and 'pychic' in p2_types:
        pass
        # no attack modifier needed
    elif 'grass' in p1_types and 'bug' in p2_types:
        p1_attack = p1_attack / 2
        p2_attack = p2_attack * 2

    elif 'grass' in p1_types and 'rock' in p2_types:
        p1_attack = p1_attack * 2

    elif 'grass' in p1_types and 'ghost' in p2_types:
        pass
        # no attack modifier needed
    elif 'grass' in p1_types and 'dragon' in p2_types:
        p1_attack = p1_attack / 2

    elif 'grass' in p1_types and 'dark' in p2_types:
        pass
        # no attack modifier needed
    elif 'grass' in p1_types and 'steel' in p2_types:
        p1_attack = p1_attack / 2

    elif 'grass' in p1_types and 'fairy' in p2_types:
        pass
        # no attack modifier needed


 # Normal type Attack modifier
    if 'normal' in p1_types and 'normal' in  p2_types:
        pass
        # no attack modifier needed
    elif 'normal' in p1_types and 'fire' in p2_types:
        pass
    elif 'normal' in p1_types and 'water' in p2_types:
        pass
    elif 'normal' in p1_types and 'electric' in p2_types:
         pass
        # no attack modifier needed
    elif 'normal' in p1_types and 'ice' in p2_types:
        pass
        # no attack modifier needed
    elif 'normal' in p1_types and 'fightiing' in p2_types:
        p2_attack = p2_attack * 2
    elif 'normal' in  p1_types and 'poison' in p2_types:
        pass
        # no attack modifier needed
    elif 'normal' in p1_types and 'ground' in p2_types:
        pass
        # no attack modifier needed
    elif 'normal' in p1_types and 'flying' in p2_types:
        pass
        # no attack modifier needed
    elif 'normal' in p1.get('types') and 'pychic' in p2_types:
        pass
        # no attack modifier needed
    elif 'normal' in p1_types and 'bug' in p2_types:
        pass
        # no attack modifier needed
    elif 'normal' in p1_types and 'rock' in p2_types:
        p1_attack = p1_attack / 2
    elif 'normal' in p1_types and 'ghost' in p2_types:
        p1_attack = 0
        p2_attack = 0
    elif 'normal' in p1_types and 'dragon' in p2_types:
        pass
        # no attack modifier needed
    elif 'normal' in p1_types and 'dark' in p2_types:
        pass
        # no attack modifier needed
    elif 'normal' in p1_types and 'steel' in p2_types:
        p1_attack = p1_attack / 2
    elif 'normal' in p1_types and 'fairy' in p2_types:
        pass
        # no attack modifier needed


# Fire type Attack modifier
    if 'fire' in p1_types and 'fire' in p2_types:
        p1_attack = p1_attack / 2
        p2_attack = p2_attack / 2
    elif 'fire' in p1_types and 'water' in p2_types:
        p1_attack = p1_attack / 2
        p2_attack = p2_attack / 2
    elif 'fire' in p1_types and 'electric' in p2_types:
         pass
    elif 'fire' in p1_types and 'ice' in p2_types:
        p1_attack = p1_attack * 2
        p2_attack = p2_attack / 2
    elif 'fire' in p1_types and 'fightiing' in p2_types:
        pass
        # no attack modifier needed
    elif 'fire' in  p1_types and 'poison' in p2_types:
        pass
        # no attack modifier needed
    elif 'fire' in p1_types and 'ground' in p2_types:
        p2_attack = p2_attack * 2

    elif 'fire' in p1_types and 'flying' in p2_types:
        pass
        # no attack modifier needed
    elif 'fire' in p1.get('types') and 'pychic' in p2_types:
        pass
        # no attack modifier needed
    elif 'fire' in p1_types and 'bug' in p2_types:
        p1_attack = p1_attack * 2
        p2_attack = p2_attack / 2
    elif 'fire' in p1_types and 'rock' in p2_types:
        p1_attack = p1_attack / 2
        p2_attack = p2_attack * 2
    elif 'fire' in p1_types and 'ghost' in p2_types:
        pass
        # no attack modifier needed
    elif 'fire' in p1_types and 'dragon' in p2_types:
        p1_attack = p1_attack / 2
    elif 'fire' in p1_types and 'dark' in p2_types:
        pass
        # no attack modifier needed
    elif 'fire' in p1_types and 'steel' in p2_types:
        p1_attack = p1_attack * 2
        p2_attack = p2_attack / 2
    elif 'fire' in p1_types and 'fairy' in p2_types:
        p2_attack = p2_attack / 2


# Water type Attack modifier
    if 'water' in p1_types and 'water' in p2_types:
        p1_attack = p1_attack / 2
        p2_attack = p2_attack / 2
    elif 'water' in p1_types and 'electric' in p2_types:
         p2_attack = p2_attack * 2
    elif 'water' in p1_types and 'ice' in p2_types:
        pass
    elif 'water' in p1_types and 'fightiing' in p2_types:
        pass
        # no attack modifier needed
    elif 'water' in  p1_types and 'poison' in p2_types:
        pass
        # no attack modifier needed
    elif 'water' in p1_types and 'ground' in p2_types:
        p1_attack = p1_attack * 2
    elif 'water' in p1_types and 'flying' in p2_types:
        pass
        # no attack modifier needed
    elif 'water' in p1.get('types') and 'pychic' in p2_types:
        pass
        # no attack modifier needed
    elif 'water' in p1_types and 'bug' in p2_types:
        pass
    elif 'water' in p1_types and 'rock' in p2_types:
        p1_attack = p1_attack * 2

    elif 'water' in p1_types and 'ghost' in p2_types:
        pass
        # no attack modifier needed
    elif 'water' in p1_types and 'dragon' in p2_types:
        p1_attack = p1_attack / 2
    elif 'water' in p1_types and 'dark' in p2_types:
        pass
        # no attack modifier needed
    elif 'water' in p1_types and 'steel' in p2_types:
        p2_attack = p2_attack / 2
    elif 'water' in p1_types and 'fairy' in p2_types:
        pass



# Electric type Attack modifier
    if 'electric' in p1_types and 'electric' in p2_types:
         p2_attack = p2_attack * 2
    elif 'electric' in p1_types and 'ice' in p2_types:
        pass
    elif 'electric' in p1_types and 'fightiing' in p2_types:
        pass
        # no attack modifier needed
    elif 'electric' in  p1_types and 'poison' in p2_types:
        pass
        # no attack modifier needed
    elif 'electric' in p1_types and 'ground' in p2_types:
        p1_attack = p1_attack * 2
    elif 'electric' in p1_types and 'flying' in p2_types:
        pass
        # no attack modifier needed
    elif 'electric' in p1.get('types') and 'pychic' in p2_types:
        pass
        # no attack modifier needed
    elif 'electric' in p1_types and 'bug' in p2_types:
        pass
    elif 'electric' in p1_types and 'rock' in p2_types:
        p1_attack = p1_attack * 2

    elif 'electric' in p1_types and 'ghost' in p2_types:
        pass
        # no attack modifier needed
    elif 'electric' in p1_types and 'dragon' in p2_types:
        p1_attack = p1_attack / 2
    elif 'electric' in p1_types and 'dark' in p2_types:
        pass
        # no attack modifier needed
    elif 'electric' in p1_types and 'steel' in p2_types:
        p2_attack = p2_attack / 2
    elif 'electric' in p1_types and 'fairy' in p2_types:
        pass


# Ice type Attack modifier
    if 'ice' in p1_types and 'ice' in p2_types:
        pass
    elif 'ice' in p1_types and 'fightiing' in p2_types:
        pass
        # no attack modifier needed
    elif 'ice' in  p1_types and 'poison' in p2_types:
        pass
        # no attack modifier needed
    elif 'ice' in p1_types and 'ground' in p2_types:
        p1_attack = p1_attack * 2
    elif 'ice' in p1_types and 'flying' in p2_types:
        pass
        # no attack modifier needed
    elif 'ice' in p1_types and 'pychic' in p2_types:
        pass
        # no attack modifier needed
    elif 'ice' in p1_types and 'bug' in p2_types:
        pass
    elif 'ice' in p1_types and 'rock' in p2_types:
        p1_attack = p1_attack * 2

    elif 'ice' in p1_types and 'ghost' in p2_types:
        pass
        # no attack modifier needed
    elif 'ice' in p1_types and 'dragon' in p2_types:
        p1_attack = p1_attack / 2
    elif 'ice' in p1_types and 'dark' in p2_types:
        pass
        # no attack modifier needed
    elif 'ice' in p1_types and 'steel' in p2_types:
        p2_attack = p2_attack / 2
    elif 'ice' in p1_types and 'fairy' in p2_types:
        pass


# Fighting type Attack modifier
    if 'fighting' in p1_types and 'fightiing' in p2_types:
        pass
        # no attack modifier needed
    elif 'fighting' in  p1_types and 'poison' in p2_types:
        pass
        # no attack modifier needed
    elif 'fighting' in p1_types and 'ground' in p2_types:
        p1_attack = p1_attack * 2
    elif 'fighting' in p1_types and 'flying' in p2_types:
        pass
        # no attack modifier needed
    elif 'fighting' in p1_types and 'pychic' in p2_types:
        pass
        # no attack modifier needed
    elif 'fighting' in p1_types and 'bug' in p2_types:
        pass
    elif 'fighting' in p1_types and 'rock' in p2_types:
        p1_attack = p1_attack * 2

    elif 'fighting' in p1_types and 'ghost' in p2_types:
        pass
        # no attack modifier needed
    elif 'fighting' in p1_types and 'dragon' in p2_types:
        p1_attack = p1_attack / 2
    elif 'fighting' in p1_types and 'dark' in p2_types:
        pass
        # no attack modifier needed
    elif 'fighting' in p1_types and 'steel' in p2_types:
        p2_attack = p2_attack / 2
    elif 'fighting' in p1_types and 'fairy' in p2_types:
        pass


# Poison type Attack modifier
    if 'poison' in  p1_types and 'poison' in p2_types:
        p1_attack = p1_attack / 2
        p2_attack = p2_attack / 2
        # no attack modifier needed
    elif 'poison' in p1_types and 'ground' in p2_types:
        p1_attack = p1_attack / 2
        p2_attack = p2_attack * 2
    elif 'poison' in p1_types and 'flying' in p2_types:
        p1_attack = p1_attack / 2
        # no attack modifier needed
    elif 'poison' in p1_types and 'pychic' in p2_types:
        p2_attack = p2_attack * 2
        # no attack modifier needed
    elif 'poison' in p1_types and 'bug' in p2_types:
        p2_attack = p2_attack / 2
    elif 'poison' in p1_types and 'rock' in p2_types:
        p1_attack = p1_attack / 2

    elif 'poison' in p1_types and 'ghost' in p2_types:
        p1_attack = p1_attack / 2
        # no attack modifier needed
    elif 'poison' in p1_types and 'dragon' in p2_types:
        pass
    elif 'poison' in p1_types and 'dark' in p2_types:
        pass
        # no attack modifier needed
    elif 'poison' in p1_types and 'steel' in p2_types:
        p1_attack = 0
    elif 'poison' in p1_types and 'fairy' in p2_types:
        pass


    p1 = {'id': p1_id, 'name': p1_name, 'attack': p1_attack, 'HP': p1_hp, 'defense': p1_defense, 'type': p1_types }
    p2 = {'id': p2_id, 'name': p2_name, 'attack': p2_attack, 'HP': p2_hp, 'defense': p2_defense, 'type': p2_types }
    # package p1 and p2 into dictionaries exactly like the input dictionaries

    return p1, p2
pokemon_1, pokemon_2 = attack_mod(p1,p2)

# %%
def battle(pokemon_1,pokemon_2):

    pokemon_2['health'] = pokemon_2['HP'] + pokemon_2['defense']
    pokemon_1['health'] = pokemon_1['HP'] + pokemon_1['defense']

    if pokemon_1['name'] == 'ditto':
        pokemon_1 = pokemon_2
    elif pokemon_2['name'] == 'ditto':
        pokemon_2 = pokemon_1

    if pokemon_1['attack'] == 0 and pokemon_2['attack'] == 0:
        print('Attacks are ineffective. The match is a draw.')

    else:
        while pokemon_1['health'] > 0 and pokemon_2['health'] > 0:
            pokemon_2['health'] = pokemon_2['health'] - pokemon_1['attack']
            if pokemon_2['health'] > 0:
                print(f"{pokemon_2['name']} has {pokemon_2['health']}HP left")
            elif pokemon_2['health'] <= 0:
                print(pokemon_2['name'] + ' is on 0HP and unable to battle. Therefore, ' + pokemon_1['name'] + ' wins!')
                break

            pokemon_1['health'] = pokemon_1['health'] - pokemon_2['attack']
            if pokemon_1['health'] > 0:
                print(f"{pokemon_1['name']} has {pokemon_1['health']}HP left")
            elif pokemon_1['health'] <= 0:
                print(pokemon_1['name'] + ' is 0HP and unable to battle. Therefore, ' + pokemon_2['name'] + ' wins!')
                break

print(battle(pokemon_1,pokemon_2))

# %%
import random

def get_pokemon_details(id):
    
    response= requests.get(f'https://pokeapi.co/api/v2/pokemon/{id}')
    pokemon_data=response.json()
    id=pokemon_data['id']
    name=pokemon_data['name']

    # to retieve the base stat of HP and its value together
    for key in pokemon_data['stats']:

        for value in key.items():
            if key['stat']['name'] == 'hp':
                HP = key['base_stat']
            elif key['stat']['name'] == 'attack':
                attack = key['base_stat']
            elif key['stat']['name'] == 'defense':
                defense = key['base_stat']


        types=[t['type']['name']for t in pokemon_data['types']]

    pokemon_details={'id':id, 'name':name, 'HP': HP, 'attack': attack, 'defense': defense, 'types':types}
    return pokemon_details

def get_random_pokemon_id():
    return random.randint(1,1281)

def pokenames_id():
    response_2 = requests.get("https://pokeapi.co/api/v2/pokemon?limit=100000&offset=0")

    response_dict_2 = response_2.json()

    results = response_dict_2['results']

    names = []

    for items in results:
        names.append(items['name'])
        # print(items['name'])

    pokemon = pd.DataFrame(names)
    pokemon.index += 1
    pokemon.columns =['Names']
    pokemon.insert(1, 'id', range(1, 1 + len(pokemon)))

    return pokemon

df = pokenames_id()

# Loading screen

print("Welcome to Pokemon Text Battle!")
print('-------------------------------------------------------')

p1_random = get_random_pokemon_id()
cpu_random = get_random_pokemon_id()
p2_random = get_random_pokemon_id()

print("Would you like to enter the game? (yes(y)/no(n)")
answer = input()
if answer == 'y' or answer == 'yes':
    print('-------------------------------------------------------')
    print("Please choose from the following options:")
    print('-------------------------------------------------------')
    print("1. Single player")
    print("2. Two players")
    players = input()
    if players == '1':
        print('-------------------------------------------------------')
        print("Welcome to Single Player Mode!")
        print('-------------------------------------------------------')
        print("Please enter your pokemon name: ")
        p1_name = input()
        

        if p1_name in df['Names'].values:
            index = df.loc[df['Names'] == p1_name]
            id_1 = index['id'].values[0]  
            print(f"Your pokemon name is: {p1_name}. Your pokemon ID is: {id_1}")
            p1 = get_pokemon_details(id_1)
            
        else:
            print("Pokemon does not exist! Randomly selecting.")
            print('-------------------------------------------------------')
            print(f"Your pokemon ID is: {p1_random}")
            p1 = get_pokemon_details(p1_random)
    
        print('-------------------------------------------------------')
        print(f"Your opponent pokemon ID is: {cpu_random}")
        p2 = get_pokemon_details(cpu_random)
    
    elif players == '2':
        print('-------------------------------------------------------')
        print("Welcome to Two Player Mode!")
        print('-------------------------------------------------------')
        print("Player 1! Please enter your pokemon name: ")
        p1_name = input()
        
        if p1_name in df['Names'].values:
            index = df.loc[df['Names'] == p1_name]
            id_1 = index['id'].values[0]  
            print(f"Your pokemon name is: {p1_name}. Your pokemon ID is: {id_1}")
            print('-------------------------------------------------------')
            p1 = get_pokemon_details(id_1)
        else:
            print("Pokemon does not exist! Randomly selecting.")
            print('-------------------------------------------------------')
            print(f"Your pokemon ID is: {p1_random}")
            print('-------------------------------------------------------')
            p1 = get_pokemon_details(p1_random)
        
        print('-------------------------------------------------------')
        print("Player 2! Please enter your pokemon name: ")
        p2_name = input()
        
        if p2_name in df['Names'].values:
            index_2 = df.loc[df['Names'] == p2_name]
            id_2 = index_2['id'].values[0]  
            print(f"Your pokemon name is: {p2_name}. Your pokemon ID is: {id_2}")
            print('-------------------------------------------------------')
            p2 = get_pokemon_details(id_2)
            
        else:
            print("Pokemon does not exist! Randomly selecting.")
            print('-------------------------------------------------------')
            print(f"Your pokemon ID is: {p2_random}")
            print('-------------------------------------------------------')
            p2 = get_pokemon_details(p2_random)
    
    else:
        print("Nope. Start game again...")
        

elif answer == 'n' or answer == 'no':
    print('-------------------------------------------------------')
    print("GAME OVER.....")
    
    

# Function to get attack modifiers


def attack_mod(p1, p2):

    p1_name = p1.get('name')
    p2_name = p2.get('name')

    p1_id = p1.get('id')
    p2_id = p2.get('id')

    p1_types = p1.get('types')
    p2_types = p2.get('types')

    p1_attack = p1.get('attack')
    p2_attack = p2.get('attack')

    p1_hp = p1.get('HP')
    p2_hp = p2.get('HP')

    p1_defense = p1.get('defense')
    p2_defense = p2.get('defense')




    # Grass type Attack modifier
    if 'grass' in p1_types and 'normal' in  p2_types:
        pass
        # no attack modifier needed
    elif 'grass' in p1_types and 'fire' in p2_types:
        p1_attack = p1_attack / 2
        p2_attack = p2_attack * 2
    elif 'grass' in p1_types and 'water' in p2_types:
        p1_attack = p1_attack * 2
        p2_attack = p2_attack / 2
    elif 'grass' in p1_types and 'electric' in p2_types:
        p2_attack = p2_attack / 2

    elif 'grass' in p1_types and 'grass' in p2_types:
        p1_attack = p1_attack / 2
        p2_attack = p2_attack / 2

    elif 'grass' in p1_types and 'ice' in p2_types:
        p2_attack =- p2_attack * 2

    elif 'grass' in p1_types and 'fightiing' in p2_types:
        pass
        # no attack modifier needed
    elif 'grass' in  p1_types and 'poison' in p2_types:
        p1_attack = p1_attack / 2
        p2_attack = p2_attack * 2

    elif 'grass' in p1_types and 'ground' in p2_types:
        p1_attack = p1_attack * 2
        p2_attack = p2_attack / 2

    elif 'grass' in p1_types and 'flying' in p2_types:
        p1_attack = p1_attack / 2
        p2_attack = p2_attack * 2

    elif 'grass' in p1.get('types') and 'pychic' in p2_types:
        pass
        # no attack modifier needed
    elif 'grass' in p1_types and 'bug' in p2_types:
        p1_attack = p1_attack / 2
        p2_attack = p2_attack * 2

    elif 'grass' in p1_types and 'rock' in p2_types:
        p1_attack = p1_attack * 2

    elif 'grass' in p1_types and 'ghost' in p2_types:
        pass
        # no attack modifier needed
    elif 'grass' in p1_types and 'dragon' in p2_types:
        p1_attack = p1_attack / 2

    elif 'grass' in p1_types and 'dark' in p2_types:
        pass
        # no attack modifier needed
    elif 'grass' in p1_types and 'steel' in p2_types:
        p1_attack = p1_attack / 2

    elif 'grass' in p1_types and 'fairy' in p2_types:
        pass
        # no attack modifier needed


 # Normal type Attack modifier
    if 'normal' in p1_types and 'normal' in  p2_types:
        pass
        # no attack modifier needed
    elif 'normal' in p1_types and 'fire' in p2_types:
        pass
    elif 'normal' in p1_types and 'water' in p2_types:
        pass
    elif 'normal' in p1_types and 'electric' in p2_types:
         pass
        # no attack modifier needed
    elif 'normal' in p1_types and 'ice' in p2_types:
        pass
        # no attack modifier needed
    elif 'normal' in p1_types and 'fightiing' in p2_types:
        p2_attack = p2_attack * 2
    elif 'normal' in  p1_types and 'poison' in p2_types:
        pass
        # no attack modifier needed
    elif 'normal' in p1_types and 'ground' in p2_types:
        pass
        # no attack modifier needed
    elif 'normal' in p1_types and 'flying' in p2_types:
        pass
        # no attack modifier needed
    elif 'normal' in p1.get('types') and 'pychic' in p2_types:
        pass
        # no attack modifier needed
    elif 'normal' in p1_types and 'bug' in p2_types:
        pass
        # no attack modifier needed
    elif 'normal' in p1_types and 'rock' in p2_types:
        p1_attack = p1_attack / 2
    elif 'normal' in p1_types and 'ghost' in p2_types:
        p1_attack = 0
        p2_attack = 0
    elif 'normal' in p1_types and 'dragon' in p2_types:
        pass
        # no attack modifier needed
    elif 'normal' in p1_types and 'dark' in p2_types:
        pass
        # no attack modifier needed
    elif 'normal' in p1_types and 'steel' in p2_types:
        p1_attack = p1_attack / 2
    elif 'normal' in p1_types and 'fairy' in p2_types:
        pass
        # no attack modifier needed


# Fire type Attack modifier
    if 'fire' in p1_types and 'fire' in p2_types:
        p1_attack = p1_attack / 2
        p2_attack = p2_attack / 2
    elif 'fire' in p1_types and 'water' in p2_types:
        p1_attack = p1_attack / 2
        p2_attack = p2_attack / 2
    elif 'fire' in p1_types and 'electric' in p2_types:
         pass
    elif 'fire' in p1_types and 'ice' in p2_types:
        p1_attack = p1_attack * 2
        p2_attack = p2_attack / 2
    elif 'fire' in p1_types and 'fightiing' in p2_types:
        pass
        # no attack modifier needed
    elif 'fire' in  p1_types and 'poison' in p2_types:
        pass
        # no attack modifier needed
    elif 'fire' in p1_types and 'ground' in p2_types:
        p2_attack = p2_attack * 2

    elif 'fire' in p1_types and 'flying' in p2_types:
        pass
        # no attack modifier needed
    elif 'fire' in p1.get('types') and 'pychic' in p2_types:
        pass
        # no attack modifier needed
    elif 'fire' in p1_types and 'bug' in p2_types:
        p1_attack = p1_attack * 2
        p2_attack = p2_attack / 2
    elif 'fire' in p1_types and 'rock' in p2_types:
        p1_attack = p1_attack / 2
        p2_attack = p2_attack * 2
    elif 'fire' in p1_types and 'ghost' in p2_types:
        pass
        # no attack modifier needed
    elif 'fire' in p1_types and 'dragon' in p2_types:
        p1_attack = p1_attack / 2
    elif 'fire' in p1_types and 'dark' in p2_types:
        pass
        # no attack modifier needed
    elif 'fire' in p1_types and 'steel' in p2_types:
        p1_attack = p1_attack * 2
        p2_attack = p2_attack / 2
    elif 'fire' in p1_types and 'fairy' in p2_types:
        p2_attack = p2_attack / 2


# Water type Attack modifier
    if 'water' in p1_types and 'water' in p2_types:
        p1_attack = p1_attack / 2
        p2_attack = p2_attack / 2
    elif 'water' in p1_types and 'electric' in p2_types:
         p2_attack = p2_attack * 2
    elif 'water' in p1_types and 'ice' in p2_types:
        pass
    elif 'water' in p1_types and 'fightiing' in p2_types:
        pass
        # no attack modifier needed
    elif 'water' in  p1_types and 'poison' in p2_types:
        pass
        # no attack modifier needed
    elif 'water' in p1_types and 'ground' in p2_types:
        p1_attack = p1_attack * 2
    elif 'water' in p1_types and 'flying' in p2_types:
        pass
        # no attack modifier needed
    elif 'water' in p1.get('types') and 'pychic' in p2_types:
        pass
        # no attack modifier needed
    elif 'water' in p1_types and 'bug' in p2_types:
        pass
    elif 'water' in p1_types and 'rock' in p2_types:
        p1_attack = p1_attack * 2

    elif 'water' in p1_types and 'ghost' in p2_types:
        pass
        # no attack modifier needed
    elif 'water' in p1_types and 'dragon' in p2_types:
        p1_attack = p1_attack / 2
    elif 'water' in p1_types and 'dark' in p2_types:
        pass
        # no attack modifier needed
    elif 'water' in p1_types and 'steel' in p2_types:
        p2_attack = p2_attack / 2
    elif 'water' in p1_types and 'fairy' in p2_types:
        pass



# Electric type Attack modifier
    if 'electric' in p1_types and 'electric' in p2_types:
         p2_attack = p2_attack * 2
    elif 'electric' in p1_types and 'ice' in p2_types:
        pass
    elif 'electric' in p1_types and 'fightiing' in p2_types:
        pass
        # no attack modifier needed
    elif 'electric' in  p1_types and 'poison' in p2_types:
        pass
        # no attack modifier needed
    elif 'electric' in p1_types and 'ground' in p2_types:
        p1_attack = p1_attack * 2
    elif 'electric' in p1_types and 'flying' in p2_types:
        pass
        # no attack modifier needed
    elif 'electric' in p1.get('types') and 'pychic' in p2_types:
        pass
        # no attack modifier needed
    elif 'electric' in p1_types and 'bug' in p2_types:
        pass
    elif 'electric' in p1_types and 'rock' in p2_types:
        p1_attack = p1_attack * 2

    elif 'electric' in p1_types and 'ghost' in p2_types:
        pass
        # no attack modifier needed
    elif 'electric' in p1_types and 'dragon' in p2_types:
        p1_attack = p1_attack / 2
    elif 'electric' in p1_types and 'dark' in p2_types:
        pass
        # no attack modifier needed
    elif 'electric' in p1_types and 'steel' in p2_types:
        p2_attack = p2_attack / 2
    elif 'electric' in p1_types and 'fairy' in p2_types:
        pass


# Ice type Attack modifier
    if 'ice' in p1_types and 'ice' in p2_types:
        pass
    elif 'ice' in p1_types and 'fightiing' in p2_types:
        pass
        # no attack modifier needed
    elif 'ice' in  p1_types and 'poison' in p2_types:
        pass
        # no attack modifier needed
    elif 'ice' in p1_types and 'ground' in p2_types:
        p1_attack = p1_attack * 2
    elif 'ice' in p1_types and 'flying' in p2_types:
        pass
        # no attack modifier needed
    elif 'ice' in p1_types and 'pychic' in p2_types:
        pass
        # no attack modifier needed
    elif 'ice' in p1_types and 'bug' in p2_types:
        pass
    elif 'ice' in p1_types and 'rock' in p2_types:
        p1_attack = p1_attack * 2

    elif 'ice' in p1_types and 'ghost' in p2_types:
        pass
        # no attack modifier needed
    elif 'ice' in p1_types and 'dragon' in p2_types:
        p1_attack = p1_attack / 2
    elif 'ice' in p1_types and 'dark' in p2_types:
        pass
        # no attack modifier needed
    elif 'ice' in p1_types and 'steel' in p2_types:
        p2_attack = p2_attack / 2
    elif 'ice' in p1_types and 'fairy' in p2_types:
        pass


# Fighting type Attack modifier
    if 'fighting' in p1_types and 'fightiing' in p2_types:
        pass
        # no attack modifier needed
    elif 'fighting' in  p1_types and 'poison' in p2_types:
        pass
        # no attack modifier needed
    elif 'fighting' in p1_types and 'ground' in p2_types:
        p1_attack = p1_attack * 2
    elif 'fighting' in p1_types and 'flying' in p2_types:
        pass
        # no attack modifier needed
    elif 'fighting' in p1_types and 'pychic' in p2_types:
        pass
        # no attack modifier needed
    elif 'fighting' in p1_types and 'bug' in p2_types:
        pass
    elif 'fighting' in p1_types and 'rock' in p2_types:
        p1_attack = p1_attack * 2

    elif 'fighting' in p1_types and 'ghost' in p2_types:
        pass
        # no attack modifier needed
    elif 'fighting' in p1_types and 'dragon' in p2_types:
        p1_attack = p1_attack / 2
    elif 'fighting' in p1_types and 'dark' in p2_types:
        pass
        # no attack modifier needed
    elif 'fighting' in p1_types and 'steel' in p2_types:
        p2_attack = p2_attack / 2
    elif 'fighting' in p1_types and 'fairy' in p2_types:
        pass


# Poison type Attack modifier
    if 'poison' in  p1_types and 'poison' in p2_types:
        p1_attack = p1_attack / 2
        p2_attack = p2_attack / 2
        # no attack modifier needed
    elif 'poison' in p1_types and 'ground' in p2_types:
        p1_attack = p1_attack / 2
        p2_attack = p2_attack * 2
    elif 'poison' in p1_types and 'flying' in p2_types:
        p1_attack = p1_attack / 2
        # no attack modifier needed
    elif 'poison' in p1_types and 'pychic' in p2_types:
        p2_attack = p2_attack * 2
        # no attack modifier needed
    elif 'poison' in p1_types and 'bug' in p2_types:
        p2_attack = p2_attack / 2
    elif 'poison' in p1_types and 'rock' in p2_types:
        p1_attack = p1_attack / 2

    elif 'poison' in p1_types and 'ghost' in p2_types:
        p1_attack = p1_attack / 2
        # no attack modifier needed
    elif 'poison' in p1_types and 'dragon' in p2_types:
        pass
    elif 'poison' in p1_types and 'dark' in p2_types:
        pass
        # no attack modifier needed
    elif 'poison' in p1_types and 'steel' in p2_types:
        p1_attack = 0
    elif 'poison' in p1_types and 'fairy' in p2_types:
        pass


    p1 = {'id': p1_id, 'name': p1_name, 'attack': p1_attack, 'HP': p1_hp, 'defense': p1_defense, 'type': p1_types }
    p2 = {'id': p2_id, 'name': p2_name, 'attack': p2_attack, 'HP': p2_hp, 'defense': p2_defense, 'type': p2_types }
    # package p1 and p2 into dictionaries exactly like the input dictionaries

    return p1, p2
pokemon_1, pokemon_2 = attack_mod(p1,p2)

print('-------------------------------------------------------')
print(pokemon_1)
print(pokemon_2)
print('-------------------------------------------------------')

# The battle

def battle(pokemon_1,pokemon_2):

    pokemon_2['health'] = pokemon_2['HP'] + pokemon_2['defense']
    pokemon_1['health'] = pokemon_1['HP'] + pokemon_1['defense']

    if pokemon_1['name'] == 'ditto':
        pokemon_1 = pokemon_2
    elif pokemon_2['name'] == 'ditto':
        pokemon_2 = pokemon_1

    if pokemon_1['attack'] == 0 and pokemon_2['attack'] == 0:
        print('Attacks are ineffective. The match is a draw.')

    else:
        while pokemon_1['health'] > 0 and pokemon_2['health'] > 0:
            pokemon_2['health'] = pokemon_2['health'] - pokemon_1['attack']
            if pokemon_2['health'] > 0:
                print(f"{pokemon_2['name']} has {pokemon_2['health']}HP left")
            elif pokemon_2['health'] <= 0:
                print(pokemon_2['name'] + ' is on 0HP and unable to battle. Therefore, ' + pokemon_1['name'] + ' wins!')
                break

            pokemon_1['health'] = pokemon_1['health'] - pokemon_2['attack']
            if pokemon_1['health'] > 0:
                print(f"{pokemon_1['name']} has {pokemon_1['health']}HP left")
            elif pokemon_1['health'] <= 0:
                print(pokemon_1['name'] + ' is 0HP and unable to battle. Therefore, ' + pokemon_2['name'] + ' wins!')
                break

print(battle(pokemon_1,pokemon_2))
print('-------------------------------------------------------')
print('End of game!')
# Out:
# Welcome to Pokemon Text Battle!
# -------------------------------------------------------
# Would you like to enter the game? (yes(y)/no(n)
# -------------------------------------------------------
# Please choose from the following options:
# -------------------------------------------------------
# 1. Single player
# 2. Two players
# -------------------------------------------------------
# Welcome to Two Player Mode!
# -------------------------------------------------------
# Player 1! Please enter your pokemon name:
# Your pokemon name is: eevee. Your pokemon ID is: 133
# -------------------------------------------------------
# -------------------------------------------------------
# Player 2! Please enter your pokemon name:
# Your pokemon name is: duskull. Your pokemon ID is: 355
# -------------------------------------------------------
# -------------------------------------------------------
# {'id': 133, 'name': 'eevee', 'attack': 0, 'HP': 55, 'defense': 50, 'type': ['normal']}
# {'id': 355, 'name': 'duskull', 'attack': 0, 'HP': 20, 'defense': 90, 'type': ['ghost']}
# -------------------------------------------------------
# Attacks are ineffective. The match is a draw.
# None
# -------------------------------------------------------
# End of game!

# %%
# def pokenames_id():
#     response_2 = requests.get("https://pokeapi.co/api/v2/pokemon?limit=100000&offset=0")

#     response_dict_2 = response_2.json()

#     results = response_dict_2['results']

#     names = []

#     for items in results:
#         names.append(items['name'])
#         # print(items['name'])

#     pokemon = pd.DataFrame(names)
#     pokemon.index += 1
#     pokemon.columns =['Names']
#     pokemon.insert(1, 'id', range(1, 1 + len(pokemon)))

#     return pokemon
# print(pokenames_id())

# %%
# print("Welcome to Pokemon Text Battle!")
# print('-------------------------------------------------------')

# p1_random = get_random_pokemon_id()
# cpu_random = get_random_pokemon_id()
# p2_random = get_random_pokemon_id()

# print("Would you like to enter the game? (yes(y)/no(n)")
# answer = input()
# if answer == 'y' or answer == 'yes':
#     print('-------------------------------------------------------')
#     print("Please choose from the following options:")
#     print('-------------------------------------------------------')
#     print("1. Single player")
#     print("2. Two players")
#     players = input()
#     if players == '1':
#         print('-------------------------------------------------------')
#         print("Welcome to Single Player Mode!")
#         print('-------------------------------------------------------')
#         print("Please enter your pokemon name: ")
#         p1_name = input()
        

#         if p1_name in df['Names'].values:
#             index = df.loc[df['Names'] == p1_name]
#             id_1 = index['id'].values[0]  
#             print(f"Your pokemon name is: {p1_name}. Your pokemon ID is: {id_1}")
#             p1 = get_pokemon_details(id_1)
            
#         else:
#             print("Pokemon does not exist! Randomly selecting.")
#             print('-------------------------------------------------------')
#             print(f"Your pokemon ID is: {p1_random}")
#             p1 = get_pokemon_details(p1_random)
    
#         print('-------------------------------------------------------')
#         print(f"Your opponent pokemon ID is: {cpu_random}")
#         p2 = get_pokemon_details(cpu_random)
    
#     elif players == '2':
#         print('-------------------------------------------------------')
#         print("Welcome to Two Player Mode!")
#         print('-------------------------------------------------------')
#         print("Player 1! Please enter your pokemon name: ")
#         p1_name = input()
        
#         if p1_name in df['Names'].values:
#             index = df.loc[df['Names'] == p1_name]
#             id_1 = index['id'].values[0]  
#             print(f"Your pokemon name is: {p1_name}. Your pokemon ID is: {id_1}")
#             p1 = get_pokemon_details(id_1)
#         else:
#             print("Pokemon does not exist! Randomly selecting.")
#             print('-------------------------------------------------------')
#             print(f"Your pokemon ID is: {p1_random}")
#             p1 = get_pokemon_details(p1_random)
        
#         print('-------------------------------------------------------')
#         print("Player 2! Please enter your pokemon name: ")
#         p2_name = input()
        
#         if p2_name in df['Names'].values:
#             index_2 = df.loc[df['Names'] == p2_name]
#             id_2 = index_2['id'].values[0]  
#             print(f"Your pokemon name is: {p2_name}. Your pokemon ID is: {id_2}")
#             p2 = get_pokemon_details(id_2)
            
#         else:
#             print("Pokemon does not exist! Randomly selecting.")
#             print('-------------------------------------------------------')
#             print(f"Your pokemon ID is: {p2_random}")
#             p2 = get_pokemon_details(p2_random)
    
#     else:
#         print("Nope. Start game again...")
#         pass

# elif answer == 'n' or answer == 'no':
#     print('-------------------------------------------------------')
#     print("GAME OVER.....")
#     pass
# Out:
# Welcome to Pokemon Text Battle!
# -------------------------------------------------------
# Would you like to enter the game? (yes(y)/no(n)
# -------------------------------------------------------
# Please choose from the following options:
# -------------------------------------------------------
# 1. Single player
# 2. Two players
# -------------------------------------------------------
# Welcome to Single Player Mode!
# -------------------------------------------------------
# Please enter your pokemon name:
# Your pokemon name is: ditto. Your pokemon ID is: 132
# -------------------------------------------------------
# Your opponent pokemon ID is: 83

# %%
# # Function to get attack modifiers

# def attack_mod(p1, p2):

#     p1_name = p1.get('name')
#     p2_name = p2.get('name')

#     p1_id = p1.get('id')
#     p2_id = p2.get('id')

#     p1_types = p1.get('types')
#     p2_types = p2.get('types')

#     p1_attack = p1.get('attack')
#     p2_attack = p2.get('attack')

#     p1_hp = p1.get('HP')
#     p2_hp = p2.get('HP')

#     p1_defense = p1.get('defense')
#     p2_defense = p2.get('defense')




#     # Grass type Attack modifier
#     if 'grass' in p1_types and 'normal' in  p2_types:
#         pass
#         # no attack modifier needed
#     elif 'grass' in p1_types and 'fire' in p2_types:
#         p1_attack = p1_attack / 2
#         p2_attack = p2_attack * 2
#     elif 'grass' in p1_types and 'water' in p2_types:
#         p1_attack = p1_attack * 2
#         p2_attack = p2_attack / 2
#     elif 'grass' in p1_types and 'electric' in p2_types:
#         p2_attack = p2_attack / 2

#     elif 'grass' in p1_types and 'grass' in p2_types:
#         p1_attack = p1_attack / 2
#         p2_attack = p2_attack / 2

#     elif 'grass' in p1_types and 'ice' in p2_types:
#         p2_attack =- p2_attack * 2

#     elif 'grass' in p1_types and 'fightiing' in p2_types:
#         pass
#         # no attack modifier needed
#     elif 'grass' in  p1_types and 'poison' in p2_types:
#         p1_attack = p1_attack / 2
#         p2_attack = p2_attack * 2

#     elif 'grass' in p1_types and 'ground' in p2_types:
#         p1_attack = p1_attack * 2
#         p2_attack = p2_attack / 2

#     elif 'grass' in p1_types and 'flying' in p2_types:
#         p1_attack = p1_attack / 2
#         p2_attack = p2_attack * 2

#     elif 'grass' in p1.get('types') and 'pychic' in p2_types:
#         pass
#         # no attack modifier needed
#     elif 'grass' in p1_types and 'bug' in p2_types:
#         p1_attack = p1_attack / 2
#         p2_attack = p2_attack * 2

#     elif 'grass' in p1_types and 'rock' in p2_types:
#         p1_attack = p1_attack * 2

#     elif 'grass' in p1_types and 'ghost' in p2_types:
#         pass
#         # no attack modifier needed
#     elif 'grass' in p1_types and 'dragon' in p2_types:
#         p1_attack = p1_attack / 2

#     elif 'grass' in p1_types and 'dark' in p2_types:
#         pass
#         # no attack modifier needed
#     elif 'grass' in p1_types and 'steel' in p2_types:
#         p1_attack = p1_attack / 2

#     elif 'grass' in p1_types and 'fairy' in p2_types:
#         pass
#         # no attack modifier needed


#  # Normal type Attack modifier
#     if 'normal' in p1_types and 'normal' in  p2_types:
#         pass
#         # no attack modifier needed
#     elif 'normal' in p1_types and 'fire' in p2_types:
#         pass
#     elif 'normal' in p1_types and 'water' in p2_types:
#         pass
#     elif 'normal' in p1_types and 'electric' in p2_types:
#          pass
#         # no attack modifier needed
#     elif 'normal' in p1_types and 'ice' in p2_types:
#         pass
#         # no attack modifier needed
#     elif 'normal' in p1_types and 'fightiing' in p2_types:
#         p2_attack = p2_attack * 2
#     elif 'normal' in  p1_types and 'poison' in p2_types:
#         pass
#         # no attack modifier needed
#     elif 'normal' in p1_types and 'ground' in p2_types:
#         pass
#         # no attack modifier needed
#     elif 'normal' in p1_types and 'flying' in p2_types:
#         pass
#         # no attack modifier needed
#     elif 'normal' in p1.get('types') and 'pychic' in p2_types:
#         pass
#         # no attack modifier needed
#     elif 'normal' in p1_types and 'bug' in p2_types:
#         pass
#         # no attack modifier needed
#     elif 'normal' in p1_types and 'rock' in p2_types:
#         p1_attack = p1_attack / 2
#     elif 'normal' in p1_types and 'ghost' in p2_types:
#         p1_attack = 0
#         p2_attack = 0
#     elif 'normal' in p1_types and 'dragon' in p2_types:
#         pass
#         # no attack modifier needed
#     elif 'normal' in p1_types and 'dark' in p2_types:
#         pass
#         # no attack modifier needed
#     elif 'normal' in p1_types and 'steel' in p2_types:
#         p1_attack = p1_attack / 2
#     elif 'normal' in p1_types and 'fairy' in p2_types:
#         pass
#         # no attack modifier needed


# # Fire type Attack modifier
#     if 'fire' in p1_types and 'fire' in p2_types:
#         p1_attack = p1_attack / 2
#         p2_attack = p2_attack / 2
#     elif 'fire' in p1_types and 'water' in p2_types:
#         p1_attack = p1_attack / 2
#         p2_attack = p2_attack / 2
#     elif 'fire' in p1_types and 'electric' in p2_types:
#          pass
#     elif 'fire' in p1_types and 'ice' in p2_types:
#         p1_attack = p1_attack * 2
#         p2_attack = p2_attack / 2
#     elif 'fire' in p1_types and 'fighting' in p2_types:
#         pass
#         # no attack modifier needed
#     elif 'fire' in  p1_types and 'poison' in p2_types:
#         pass
#         # no attack modifier needed
#     elif 'fire' in p1_types and 'ground' in p2_types:
#         p2_attack = p2_attack * 2

#     elif 'fire' in p1_types and 'flying' in p2_types:
#         pass
#         # no attack modifier needed
#     elif 'fire' in p1.get('types') and 'pychic' in p2_types:
#         pass
#         # no attack modifier needed
#     elif 'fire' in p1_types and 'bug' in p2_types:
#         p1_attack = p1_attack * 2
#         p2_attack = p2_attack / 2
#     elif 'fire' in p1_types and 'rock' in p2_types:
#         p1_attack = p1_attack / 2
#         p2_attack = p2_attack * 2
#     elif 'fire' in p1_types and 'ghost' in p2_types:
#         pass
#         # no attack modifier needed
#     elif 'fire' in p1_types and 'dragon' in p2_types:
#         p1_attack = p1_attack / 2
#     elif 'fire' in p1_types and 'dark' in p2_types:
#         pass
#         # no attack modifier needed
#     elif 'fire' in p1_types and 'steel' in p2_types:
#         p1_attack = p1_attack * 2
#         p2_attack = p2_attack / 2
#     elif 'fire' in p1_types and 'fairy' in p2_types:
#         p2_attack = p2_attack / 2


#     print(p1_attack)
#     print(p2_attack)
#     p1 = {'id': p1_id, 'name': p1_name, 'attack': p1_attack, 'HP': p1_hp, 'defense': p1_defense, 'type': p1_types }
#     p2 = {'id': p2_id, 'name': p2_name, 'attack': p2_attack, 'HP': p2_hp, 'defense': p2_defense, 'type': p2_types }
#     # package p1 and p2 into dictionaries exactly like the input dictionaries

#     return p1, p2
# pokemon_1, pokemon_2 = attack_mod(p1,p2)

# print(pokemon_1)
# print(pokemon_2)
# Out:
# 48
# 90
# {'id': 132, 'name': 'ditto', 'attack': 48, 'HP': 48, 'defense': 48, 'type': ['normal']}
# {'id': 83, 'name': 'farfetchd', 'attack': 90, 'HP': 52, 'defense': 55, 'type': ['normal', 'flying']}

# %%
# def battle(pokemon_1,pokemon_2):

#     pokemon_2['health'] = pokemon_2['HP'] + pokemon_2['defense']
#     pokemon_1['health'] = pokemon_1['HP'] + pokemon_1['defense']
    
#     if pokemon_1['name'] == 'ditto':
#         pokemon_1 = pokemon_2
#     elif pokemon_2['name'] == 'ditto':
#         pokemon_2 = pokemon_1
    
#     if pokemon_1['attack'] == 0 and pokemon_2['attack'] == 0:
#         print('Attacks are ineffective. The match is a draw.')
        
#     else:
#         while pokemon_1['health'] > 0 and pokemon_2['health'] > 0:
#             pokemon_2['health'] = pokemon_2['health'] - pokemon_1['attack']
#             if pokemon_2['health'] > 0:
#                 print(f"{pokemon_2['name']} has {pokemon_2['health']}HP left")
#             elif pokemon_2['health'] <= 0:
#                 print(pokemon_2['name'] + ' is on 0HP and unable to battle. Therefore, ' + pokemon_1['name'] + ' wins!')
#                 break
            
#             pokemon_1['health'] = pokemon_1['health'] - pokemon_2['attack']
#             if pokemon_1['health'] > 0:
#                 print(f"{pokemon_1['name']} has {pokemon_1['health']}HP left")
#             elif pokemon_1['health'] <= 0:
#                 print(pokemon_1['name'] + ' is 0HP and unable to battle. Therefore, ' + pokemon_2['name'] + ' wins!')
#                 break

# print(battle(pokemon_1,pokemon_2))
# Out:
# farfetchd has 17HP left
# farfetchd is 0HP and unable to battle. Therefore, farfetchd wins!
# None

# %%
# def pokenames_id():
#     response_2 = requests.get("https://pokeapi.co/api/v2/pokemon?limit=100000&offset=0")

#     response_dict_2 = response_2.json()

#     results = response_dict_2['results']

#     names = []

#     for items in results:
#         names.append(items['name'])
#         # print(items['name'])

#     pokemon = pd.DataFrame(names)
#     pokemon.index += 1
#     pokemon.columns =['Names']
#     pokemon.insert(1, 'id', range(1, 1 + len(pokemon)))

#     return pokemon
# print(pokenames_id())

# %%
# import requests
# import pandas as pd

# url = "https://pokeapi.co/api/v2/pokemon?limit=100000&offset=0"

# response = requests.get(url)
# data = response.json()

# df = pd.DataFrame(data["results"])

# print(df.head())
# Out:
#          name                                   url
# 0   bulbasaur  https://pokeapi.co/api/v2/pokemon/1/
# 1     ivysaur  https://pokeapi.co/api/v2/pokemon/2/
# 2    venusaur  https://pokeapi.co/api/v2/pokemon/3/
# 3  charmander  https://pokeapi.co/api/v2/pokemon/4/
# 4  charmeleon  https://pokeapi.co/api/v2/pokemon/5/

# %%
# import requests
# import pandas as pd

# url = "https://pokeapi.co/api/v2/pokemon?limit=100000&offset=0"

# response = requests.get(url)
# data = response.json()

# df = pd.DataFrame(data["results"])

# print(df.head())

# %%
# import random

# def get_num_players():
#     while True:
#         num_players = input("How many players? (1 or 2): ")
#         if num_players in ["1", "2"]:
#             return int(num_players)
#         print("Invalid input. Please enter 1 or 2.")

# def pokenames_id():
#     response_2 = requests.get("https://pokeapi.co/api/v2/pokemon?limit=100000&offset=0")

#     response_dict_2 = response_2.json()
#     results = response_dict_2['results']
#     names = []

#     for items in results:
#         names.append(items['name'])
#         # print(items['name'])

#     pokemon = pd.DataFrame(names)
#     pokemon.index += 1

#     pokemon.columns =['Names']
#     return pokemon

# def get_pokemon_name():
#     poke_name = input("Enter the name of your Pokemon: ")
#     if poke_name in pokenames_id():
#         print('hello')
#     return 

# def get_random_pokemon():
#     pokemon_id = random.randint(1, 1281)
#     return requests.get(f"https://pokeapi.co/api/v2/pokemon/{pokemon_id}").json()

# num_players = get_num_players()

# if num_players == 1:
#     print("You have chosen to play with one player.")
#     pokemon_choice = input("Do you want to choose your Pokemon by name? (y/n): ")
#     if pokemon_choice.lower() == "y":
#         pokemon_name = get_pokemon_name()
#     else:
#         pokemon_data = get_random_pokemon()
# else:
#     print("You have chosen to play with two players.")
#     player1_choice = input("Player 1: Do you want to choose your Pokemon by name? (y/n): ")
#     if player1_choice.lower() == "y":
#         player1_name = get_pokemon_name()
#     else:
#         player1_data = get_random_pokemon()

#     player2_choice = input("Player 2: Do you want to choose your Pokemon by name? (y/n): ")
#     if player2_choice.lower() == "y":
#         player2_name = get_pokemon_name()
#     else:
#         player2_data = get_random_pokemon()
# Out:
# You have chosen to play with one player.

# %%
# import requests

# def get_pokemon_details(id):

#     response_3 = requests.get(f'https://pokeapi.co/api/v2/pokemon/{id}')

#     pokemon_data=response_3.json()
#     id=pokemon_data['id']
#     name=pokemon_data['name']
#     HP=pokemon_data.get('stats["0"]')
#     for key in pokemon_data['stats']:
#         print(key)
#         base_stat= key['base_stat']
#         base_stat
#     attack=pokemon_data.get('attack')
#     defence=pokemon_data.get('defence')
#     types=[t['type']['name']for t in pokemon_data['types']]

#     pokemon_details={'id':id, 'name':name, 'HP': HP, 'attack': attack, 'defence': defence, 'types':types}
#     return pokemon_details

# %%
# def get_pokemon_details(id):
    
#     response= requests.get(f'https://pokeapi.co/api/v2/pokemon/{id}')
#     pokemon_data=response.json()
#     id=pokemon_data['id']
#     name=pokemon_data['name']

#     # to retieve the base stat of HP and its value together
#     for key in pokemon_data['stats']:

#         for value in key.items():
#             if key['stat']['name'] == 'hp':
#                 HP = key['base_stat']
#             elif key['stat']['name'] == 'attack':
#                 attack = key['base_stat']
#             elif key['stat']['name'] == 'defense':
#                 defense = key['base_stat']


#      # to retieve the base stat of HP and its value together

#         types=[t['type']['name']for t in pokemon_data['types']]

#     pokemon_details={'id':id, 'name':name, 'HP': HP, 'attack': attack, 'defense': defense, 'types':types}
#     return pokemon_details
# get_pokemon_details(1)
# Out:
# {'id': 1,
#  'name': 'bulbasaur',
#  'HP': 45,
#  'attack': 49,
#  'defense': 49,
#  'types': ['grass', 'poison']}

# %%
# while pokemon_1['HP'] > 0 and pokemon_2['HP'] > 0:
#     print(f"{pokemon_1['name']} has {pokemon_1['HP']} left")
#     pokemon_2['HP'] = pokemon_2['HP'] - pokemon_1['attack']
#     if pokemon_2['HP'] <= 0:
#         print(pokemon_1['name'] + ' wins!')
#         break
    
#     print(f"{pokemon_2['name']} has {pokemon_2['HP']} left")
#     pokemon_1['HP'] = pokemon_1['HP'] - pokemon_2['attack']
#     if pokemon_1['HP'] <= 0:
#         print(pokemon_2['name'] + ' wins!')
#         break
# Out:
# sandile has 50 left
# wailord has 98 left
# wailord wins!

# %%
# while pokemon_1['HP'] > 0 and pokemon_2['HP'] > 0:
#     pokemon_2['HP'] = pokemon_2['HP'] - pokemon_1['attack']
#     pokemon_1['HP'] = pokemon_1['HP'] - pokemon_2['attack']
#     if pokemon_1['HP'] <= 0:
#         print(pokemon_2['name'] + ' wins!')
#     elif pokemon_2['HP'] <= 0:
    
#         print(pokemon_1['name'] + ' wins!')

# %%
# def get_pokemon_details(ids):
#     pokemon_list = []
#     for id in ids:
#         response= requests.get(f'https://pokeapi.co/api/v2/pokemon/{id}')
#         pokemon_data=response.json()
#         name=pokemon_data['name']

#         # to retrieve the base stat of HP and its value together
#         for key in pokemon_data['stats']:
#             if key['stat']['name'] == 'hp':
#                 HP = key['base_stat']
#             elif key['stat']['name'] == 'attack':
#                 attack = key['base_stat']
#             elif key['stat']['name'] == 'defense':
#                 defense = key['base_stat']

#         # to retrieve the types of the pokemon
#         types=[t['type']['name']for t in pokemon_data['types']]

#         pokemon_details={'id':id, 'name':name, 'HP': HP, 'attack': attack, 'defense': defense, 'types':types}
#         if len(pokemon_list) == 2:
#              print(pokemon_list)
#         else:
#             pokemon_list.append(pokemon_details)
#     if len(pokemon_list) < 2:
#         print('not enough Pokemon for the battle')
#     elif len(pokemon_list) > 2:
#         print('too much Pokemon for the battle')
# pokemon1= get_pokemon_details([4,9])
